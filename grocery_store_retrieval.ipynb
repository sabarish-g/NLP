# %%
# !pip install rank-bm25 llama-index llama_hub transformers accelerate sentence_transformers
# Out:
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.10/dist-packages (0.8.54)
# Requirement already satisfied: llama_hub in /usr/local/lib/python3.10/dist-packages (0.0.40)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.34.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank-bm25) (1.23.5)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index) (2.0.22)
# Requirement already satisfied: aiostream<0.6.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.5.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (2023.6.0)
# Requirement already satisfied: langchain>=0.0.303 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.0.325)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.5.8)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index) (3.8.1)
# Requirement already satisfied: openai>=0.26.4 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.28.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.5.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.5.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (4.5.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (0.9.0)
# Requirement already satisfied: urllib3<2 in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.26.18)
# Requirement already satisfied: atlassian-python-api in /usr/local/lib/python3.10/dist-packages (from llama_hub) (3.41.3)
# Requirement already satisfied: html2text in /usr/local/lib/python3.10/dist-packages (from llama_hub) (2020.1.16)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from llama_hub) (5.9.5)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from llama_hub) (1.3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->llama-index) (3.20.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index) (1.14.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index) (3.8.6)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index) (4.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index) (0.0.53)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.303->llama-index) (1.10.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index) (3.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from atlassian-python-api->llama_hub) (1.16.0)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.10/dist-packages (from atlassian-python-api->llama_hub) (3.2.2)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from atlassian-python-api->llama_hub) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama-index) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain>=0.0.303->llama-index) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain>=0.0.303->llama-index) (1.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.303->llama-index) (2.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
from llama_index.llms import OpenAI
from tqdm.asyncio import tqdm
from llama_index import VectorStoreIndex, ServiceContext, PromptTemplate, Document
from llama_index.retrievers import BM25Retriever
from llama_index.response.notebook_utils import display_source_node
import nest_asyncio


nest_asyncio.apply()

# %%
df = pd.read_excel('dataset_grocery.xlsx')
id_col = []
for i in range(len(df)):
  id_col.append(np.random.randint(1e7, 1e8))

df['ID'] = id_col
df['lower_description'] = df['Description'].str.lower()
df.head()
# Out:
#                                          Description Subcategory Category  \
# 0     Marketside Fresh Vegetable Medley Blend, 12 oz   Vegetable  Produce
# 1                      Fresh Green Bell Pepper, Each   Vegetable  Produce
# 2                              Fresh Cilantro, Bunch   Vegetable  Produce
# 3                            Fresh Roma Tomato, Each   Vegetable  Produce
# 4  Fresh Jalapeno Pepper, Approx. 3-5 per 0.25 Pound   Vegetable  Produce
#
#          ID                                  lower_description
# 0  75027076     marketside fresh vegetable medley blend, 12 oz
# 1  15186230                      fresh green bell pepper, each
# 2  26810050                              fresh cilantro, bunch
# 3  80385241                            fresh roma tomato, each
# 4  75384478  fresh jalapeno pepper, approx. 3-5 per 0.25 pound

# %%
#create vector db

docs = []
for i, row in df.iterrows():
    docs.append(Document(text = row['lower_description'],
                         doc_id = row['ID'],
                         extra_info = {'category' : row['Category'],
                                     'subcategory':row['Subcategory']}))
print(len(docs))
# Out:
# 106

# %%
docs[0]
# Out:
# Document(id_='75027076', embedding=None, metadata={'category': 'Produce', 'subcategory': 'Vegetable'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='b41473d67b6462a55f50eb3bb69aa471ea9a87918c8884a0c38adee9fd62bea6', text='marketside fresh vegetable medley blend, 12 oz', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
from langchain.embeddings.huggingface import HuggingFaceBgeEmbeddings
from llama_index import ServiceContext

embed_model = HuggingFaceBgeEmbeddings(model_name="BAAI/bge-base-en")

# %%
service_context = ServiceContext.from_defaults(chunk_size = 512, embed_model = embed_model, llm = None)
# Out:
# LLM is explicitly disabled. Using MockLLM.

# %%
index  = VectorStoreIndex.from_documents(docs, service_context=service_context)

# %%
async def run_queries(queries, retrievers):
  tasks = []
  for query in queries:
    for i, retriever in enumerate(retrievers):
      tasks.append(retriever.aretrieve(query))

  task_results = await tqdm.gather(*tasks)
  results_dict = {}

  for i, (query, query_result) in enumerate(zip(queries, task_results)):
    results_dict[(query, i)] = query_result

  return results_dict

# %%
vector_retriever = index.as_retriever(similarity_top_k = 3)
bm25_retriever = BM25Retriever.from_defaults(docstore = index.docstore, similarity_top_k = 3)

# %%
def fuse_results(results_dict, similarity_top_k: int = 3):
    """Fuse results."""
    k = 60.0  # `k` is a parameter used to control the impact of outlier rankings.
    fused_scores = {}
    text_to_node = {}

    # compute reciprocal rank scores
    for nodes_with_scores in results_dict.values():
        for rank, node_with_score in enumerate(
            sorted(
                nodes_with_scores, key=lambda x: x.score or 0.0, reverse=True
            )
        ):
            text = node_with_score.node.get_content()
            text_to_node[text] = node_with_score
            if text not in fused_scores:
                fused_scores[text] = 0.0
            fused_scores[text] += 1.0 / (rank + k)

    # sort results
    reranked_results = dict(
        sorted(fused_scores.items(), key=lambda x: x[1], reverse=True)
    )

    # adjust node scores
    reranked_nodes: List[NodeWithScore] = []
    for text, score in reranked_results.items():
        reranked_nodes.append(text_to_node[text])
        reranked_nodes[-1].score = score

    return reranked_nodes[:similarity_top_k]

# %%
# queries = ['Great Value Large White Eggs, 60 Count']
# queries = ['Boneless Pork Loin Country Style Ribs, 2.3 - 3.8 lb Tray']
# queries = ['Tree Hut Coconut Lime Shea Sugar Exfoliating and Hydrating Body Scrub, 18 oz.']
# queries = ['Wet Ones Antibacterial Fresh Scent Hand Wipes 40 Ct Canister, Hypoallergenic, Kills Germs, Leaves Hands Feeling Clean']
# queries = ['Nestle Nesquik Chocolate Lowfat Milk, Ready to Drink, 14 fl oz']
# queries = ['Tuscan Dairy Farms Whole Milk, Vitamin D Milk Quart - 1 Milk Bottle']
# queries = ['Fresh Green Kale, 1 lb Bag'] #does work best
# queries = ['Organic Marketside Fresh Kale Blend, Rainbow, Green, Red and Lacinato Kale, 1 lb Bag']
# queries = ['Great Value Organic Ground Cardamom, 1.8 oz']
queries = ['Tostitos Scoops! Tortilla Chips Party Size, 14.5 oz Bag']
# queries = ['spaghetti']

# %%
results_dict = await run_queries(queries, [vector_retriever, bm25_retriever])
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  9.34it/s]

# %%
final_results = fuse_results(results_dict)
print(queries[0])
for n in final_results:
    display_source_node(n, source_length=500)
# Out:
# Tostitos Scoops! Tortilla Chips Party Size, 14.5 oz Bag
# **Node ID:** 0d3cc520-7e11-4b30-818f-5ca354f87cb7<br>**Similarity:** 0.016666666666666666<br>**Text:** sabra snackers fresh guacamole dip and rolled tortilla chips, 2.8 oz, 1 pack<br>
# **Node ID:** a12767f6-9e64-42fc-a301-d53fc52c0bb3<br>**Similarity:** 0.01639344262295082<br>**Text:** transocean seafood snackers, snack size leg style imitation crab, 1 - 3 oz small plastic bag<br>
# **Node ID:** 6cd5a25d-b7c9-4764-9fca-4a78ef4f6432<br>**Similarity:** 0.016129032258064516<br>**Text:** wholly guacamole chunky bowl 15 oz<br>

# %%
# queries = ['Great Value Large White Eggs, 60 Count']
# queries = ['Boneless Pork Loin Country Style Ribs, 2.3 - 3.8 lb Tray']
# queries = ['Tree Hut Coconut Lime Shea Sugar Exfoliating and Hydrating Body Scrub, 18 oz.']
# queries = ['Wet Ones Antibacterial Fresh Scent Hand Wipes 40 Ct Canister, Hypoallergenic, Kills Germs, Leaves Hands Feeling Clean']
queries = ['Nestle Nesquik Chocolate Lowfat Milk, Ready to Drink, 14 fl oz']
# queries = ['Tuscan Dairy Farms Whole Milk, Vitamin D Milk Quart - 1 Milk Bottle']
# queries = ['Fresh Green Kale, 1 lb Bag'] #does work best
# queries = ['Organic Marketside Fresh Kale Blend, Rainbow, Green, Red and Lacinato Kale, 1 lb Bag']
# queries = ['Great Value Organic Ground Cardamom, 1.8 oz']
# queries = ['Tostitos Scoops! Tortilla Chips Party Size, 14.5 oz Bag']
# queries = ['spaghetti']
results_dict = await run_queries(queries, [vector_retriever, bm25_retriever])
final_results = fuse_results(results_dict)
print(queries[0])
for n in final_results:
    display_source_node(n, source_length=500)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:00<00:00,  2.22it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.65it/s]
# Nestle Nesquik Chocolate Lowfat Milk, Ready to Drink, 14 fl oz
# **Node ID:** 7df4d94f-0467-41d4-aa62-3bc0bd84af9f<br>**Similarity:** 0.016666666666666666<br>**Text:** great value 1% low fat milk, gallon, 128 fl oz<br>
# **Node ID:** f9bcf19c-086c-4db0-9d25-809da1949d3c<br>**Similarity:** 0.01639344262295082<br>**Text:** lactaid 2% reduced fat milk, 96 oz<br>
# **Node ID:** 8f08705b-54f2-49b3-ae36-a5deb3fef0e3<br>**Similarity:** 0.016129032258064516<br>**Text:** lactaid whole milk, 96 oz<br>

# %%
# queries = ['Great Value Large White Eggs, 60 Count']
# queries = ['Boneless Pork Loin Country Style Ribs, 2.3 - 3.8 lb Tray']
queries = ['Tree Hut Coconut Lime Shea Sugar Exfoliating and Hydrating Body Scrub, 18 oz.']
# queries = ['Wet Ones Antibacterial Fresh Scent Hand Wipes 40 Ct Canister, Hypoallergenic, Kills Germs, Leaves Hands Feeling Clean']
# queries = ['Nestle Nesquik Chocolate Lowfat Milk, Ready to Drink, 14 fl oz']
# queries = ['Tuscan Dairy Farms Whole Milk, Vitamin D Milk Quart - 1 Milk Bottle']
# queries = ['Fresh Green Kale, 1 lb Bag'] #does work best
# queries = ['Organic Marketside Fresh Kale Blend, Rainbow, Green, Red and Lacinato Kale, 1 lb Bag']
# queries = ['Great Value Organic Ground Cardamom, 1.8 oz']
# queries = ['Tostitos Scoops! Tortilla Chips Party Size, 14.5 oz Bag']
# queries = ['spaghetti']
results_dict = await run_queries(queries, [vector_retriever, bm25_retriever])
final_results = fuse_results(results_dict)
print(queries[0])
for n in final_results:
    display_source_node(n, source_length=500)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00,  6.19it/s]
# Tree Hut Coconut Lime Shea Sugar Exfoliating and Hydrating Body Scrub, 18 oz.
# **Node ID:** 27b10617-5cfb-456c-8286-bdf70dd973e6<br>**Similarity:** 0.016666666666666666<br>**Text:** dove white beauty bar 4 oz, 8 ct<br>
# **Node ID:** bc357483-e448-4f53-b7e3-0e3e1120ee0f<br>**Similarity:** 0.01639344262295082<br>**Text:** irish spring bar soap for men, aloe mist deodorant bar soap, 3.7 oz, 12 pack<br>
# **Node ID:** 3097441a-38b1-47d5-a156-f79ce7d99092<br>**Similarity:** 0.016129032258064516<br>**Text:** coast refreshing deodorant bar soap, classic scent, 3.2 oz, 8 bars<br>

# %%
# queries = ['Great Value Large White Eggs, 60 Count']
queries = ['Boneless Pork Loin Country Style Ribs, 2.3 - 3.8 lb Tray']
# queries = ['Tree Hut Coconut Lime Shea Sugar Exfoliating and Hydrating Body Scrub, 18 oz.']
# queries = ['Wet Ones Antibacterial Fresh Scent Hand Wipes 40 Ct Canister, Hypoallergenic, Kills Germs, Leaves Hands Feeling Clean']
# queries = ['Nestle Nesquik Chocolate Lowfat Milk, Ready to Drink, 14 fl oz']
# queries = ['Tuscan Dairy Farms Whole Milk, Vitamin D Milk Quart - 1 Milk Bottle']
# queries = ['Fresh Green Kale, 1 lb Bag'] #does work best
# queries = ['Organic Marketside Fresh Kale Blend, Rainbow, Green, Red and Lacinato Kale, 1 lb Bag']
# queries = ['Great Value Organic Ground Cardamom, 1.8 oz']
# queries = ['Tostitos Scoops! Tortilla Chips Party Size, 14.5 oz Bag']
# queries = ['spaghetti']
results_dict = await run_queries(queries, [vector_retriever, bm25_retriever])
final_results = fuse_results(results_dict)
print(queries[0])
for n in final_results:
    display_source_node(n, source_length=500)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00,  7.36it/s]
# Boneless Pork Loin Country Style Ribs, 2.3 - 3.8 lb Tray
# **Node ID:** ddd1f171-a2ea-4f96-aa2c-f1d309fcad47<br>**Similarity:** 0.016666666666666666<br>**Text:** pork country style ribs boneless, 1.1 - 2.5 lb tray<br>
# **Node ID:** 3358aed3-701c-4635-8f43-ead51368ad7a<br>**Similarity:** 0.01639344262295082<br>**Text:** pork ribeye chops boneless, 2.0 - 3.3 lb tray<br>
# **Node ID:** 8b430b85-cafa-4f9e-926a-777c45dc55a8<br>**Similarity:** 0.016129032258064516<br>**Text:** pork stew meat boneless, 0.9 - 2.0 lb tray<br>

# %%
pd.set_option('display.max_rows', 150)
df
# Out:
#                                            Description       Subcategory  \
# 0       Marketside Fresh Vegetable Medley Blend, 12 oz         Vegetable
# 1                        Fresh Green Bell Pepper, Each         Vegetable
# 2                                Fresh Cilantro, Bunch         Vegetable
# 3                              Fresh Roma Tomato, Each         Vegetable
# 4    Fresh Jalapeno Pepper, Approx. 3-5 per 0.25 Pound         Vegetable
# 5                                 Fresh Cucumber, Each         Vegetable
# 6           Marketside Fresh Spinach, 10 oz Bag, Fresh         Vegetable
# 7          Great Value Chopped Spinach, 12 oz (Frozen)  Frozen Vegetable
# 8    Great Value Steamable Mixed Vegetables, Frozen...  Frozen Vegetable
# 9    Great Value Broccoli & Cauliflower, 12 oz (Fro...  Frozen Vegetable
# 10   Great Value Frozen Peas & Carrots, 12 oz Steam...  Frozen Vegetable
# 11                              Fresh Honeycrisp Apple             Fruit
# 12   Del Monte Red Grapefruit in 100% Juice, 20.0 o...             Fruit
# 13                         Fresh Clementines, 3 lb Bag             Fruit
# 14   Fresh Green Seedless Grapes, Bag (2.25 lbs/bag...             Fruit
# 15                   Fresh Honeycrisp Apples, 3 lb Bag             Fruit
# 16                    Fresh Strawberries, 1 lb Package             Fruit
# 17   Fresh Red Seedless Grapes, Bag (2.25 lbs/Bag E...             Fruit
# 18                      Fresh Granny Smith Apple, Each             Fruit
# 19                              Fresh Cantaloupe, Each             Fruit
# 20                                    Fresh Plum, Each             Fruit
# 21                          Fresh Mangoes, Each, Sweet             Fruit
# 22                  Fresh Blueberries, 18 oz Container             Fruit
# 23                       Fresh Navel Oranges, 4 lb Bag             Fruit
# 24             Great Value Blueberries, 48 oz (Frozen)      Frozen Fruit
# 25   Tru Fru Natures Strawberries Frozen Fresh in W...      Frozen Fruit
# 26        Great Value Frozen Whole Berry Medley, 16 Oz      Frozen Fruit
# 27   Great Value, Mild Ground Italian Sausage, Pork...           Sausage
# 28   Johnsonville Beddar With Cheddar Smoked Sausag...           Sausage
# 29   Smithfield Marinated Roasted Garlic & Herb Fre...              Pork
# 30   Pork Country Style Ribs Boneless, 1.1 - 2.5 lb...              Pork
# 31       Pork Ribeye Chops Boneless, 2.0 - 3.3 lb Tray              Pork
# 32   Smithfield Fresh Pork Center Cut Loin Boneless...              Pork
# 33   Pork Center Cut Loin Chops Bone-in, 1.6 - 2.6 ...              Pork
# 34          Pork Stew Meat Boneless, 0.9 - 2.0 lb Tray              Pork
# 35   Shady Brook Farms® 93% Lean / 7% Fat Ground Tu...            Turkey
# 36   Shady Brook Farms® Turkey Drumsticks, 3 Pieces...            Turkey
# 37   Villari Brothers, 100% Gluten Free, Hickory Sm...            Turkey
# 38   Butterball Original Seasoned Frozen Turkey Bur...            Turkey
# 39   Land O' Frost Premium Honey Smoked Turkey Brea...            Turkey
# 40   All Natural* 80% Lean/20% Fat Ground Beef Chuc...              Beef
# 41   Beef Choice Angus Chuck Roast, 2.25 - 3.38 lb ...              Beef
# 42    Beef Bottom Round Steak Thin, 0.34 - 2.0 lb Tray              Beef
# 43   All Natural* 93% Lean/7% Fat Lean Ground Beef,...              Beef
# 44   All Natural* 73% Lean/27% Fat Ground Beef, 3 l...              Beef
# 45   Great Value Frozen Raw Jumbo Shell-on, Tail-on...            Shrimp
# 46   Great Value Frozen Wild Caught Pacific Whiting...            Fillet
# 47         Dockside Classics Premium Crab Cakes, 12 oz              Crab
# 48   Fresh Skinless Atlantic Salmon Portions, 0.95 ...            Salmon
# 49   Military Surplus Freeze Dried Salmon Fillets L...            Salmon
# 50   Transocean Seafood Snackers, Snack Size Leg St...              Crab
# 51   Great Value Frozen Tilapia Skinless & Boneless...           Tilapia
# 52             Bumble Bee Tuna, Teriyaki 2.5 oz. Pouch              Tuna
# 53   Chicken of the Sea Wild Caught Alaskan Pink Sa...            Salmon
# 54   Ecuagold Frozen Raw Shrimp Head-On, 2 lb (14-2...            Shrimp
# 55   PrimeWaters Atlantic Salmon, Traceable and Sus...            Salmon
# 56           Freshness Guaranteed Mini Pecan Pie, 4 oz              Cake
# 57    WHOLLY Guacamole Spicy Avocado Verde Salsa 10 oz         Vegetable
# 58   WHOLLY Guacamole Classic Mild Mini Single Serv...         Vegetable
# 59                  WHOLLY Guacamole Chunky Bowl 15 oz         Vegetable
# 60   Sabra Snackers Fresh Guacamole Dip and Rolled ...         Vegetable
# 61                           Fresh Hass Avocados, Each         Vegetable
# 62             Fresh Small Hass Avocado Bag, 5-6 Count         Vegetable
# 63            Fresh Large Hass Avocado Bag, 3- 4 Count         Vegetable
# 64           Kraft Parmesan Grated Cheese, 8 oz Shaker            Cheese
# 65        Great Value Sweet Cream Salted Butter, 16 oz            Butter
# 66   Great Value Cream Cheese Brick, 8 oz (Refriger...            Cheese
# 67   Daisy Pure and Natural Sour Cream, Regular,16 ...        Sour Cream
# 68   Great Value Finely Shredded Sharp Cheddar Chee...            Cheese
# 69   Great Value Mozzarella String Cheese Sticks, 1...            Cheese
# 70                           Lactaid Whole Milk, 96 oz              Milk
# 71                  Lactaid 2% Reduced Fat Milk, 96 oz              Milk
# 72      Great Value 1% Low Fat Milk, Gallon, 128 fl oz              Milk
# 73   Great Value Skim Fat Free Milk, Half Gallon, 6...              Milk
# 74   Horizon Organic Whole High Vitamin D Milk, Hal...              Milk
# 75   Great Value Cage Free White Eggs, Large, 18 Count              Eggs
# 76   Nellie's Free-Range Grade A Brown Eggs, Large,...              Eggs
# 77   Irish Spring Bar Soap for Men, Aloe Mist Deodo...         Hand Soap
# 78   Softsoap Liquid Hand Soap Refill, Aquarium, 50 oz         Hand Soap
# 79                    Dove White Beauty Bar 4 Oz, 8 Ct         Hand Soap
# 80   Coast Refreshing Deodorant Bar Soap, Classic S...         Hand Soap
# 81   Kirk's Original Fresh Scent Gentle Castile Soa...         Hand Soap
# 82   Purex Liquid Laundry Detergent, Mountain Breez...         Detergent
# 83   Persil Discs Laundry Detergent Pacs, Original,...         Detergent
# 84   Tide Simply Liquid Laundry Detergent, Refreshi...         Detergent
# 85   Xtra Plus OxiClean, 131 Loads Liquid Laundry D...         Detergent
# 86   Tide Power Pods Laundry Detergent Soap Packs w...         Detergent
# 87             Barilla Classic Mini Penne Pasta, 16 oz             Pasta
# 88                     Great Value Rotini Pasta, 16 oz             Pasta
# 89   Knorr Pasta Sides Chicken Fettuccine, Cooks in...             Pasta
# 90                         Great Value Linguine, 16 oz             Pasta
# 91   Ragu Old World Style Traditional Sauce, Made w...             Pasta
# 92   Ragu Chunky Tomato, Garlic and Onion Pasta Sau...       Pasta Sauce
# 93   Classico Tomato & Basil Spaghetti Pasta Sauce,...       Pasta Sauce
# 94   Prego Pasta Sauce, Italian Tomato Sauce with R...       Pasta Sauce
# 95   Rao's Homemade Tomato Sauce | Tomato Basil | 2...       Pasta Sauce
# 96      Great Value Classic Alfredo Pasta Sauce, 16 oz       Pasta Sauce
# 97          Great Value Traditional Pasta Sauce, 24 oz       Pasta Sauce
# 98   McCormick Cinnamon - Ground, 2.37 oz Mixed Spi...            Spices
# 99   McCormick Garlic Powder, 3.12 oz Mixed Spices ...            Spices
# 100                        Great Value Paprika, 2.5 oz            Spices
# 101             Great Value Italian Seasoning, 0.95 Oz            Spices
# 102                   Great Value Ground Cumin, 2.5 oz            Spices
# 103                 Great Value Parsley Flakes, 0.4 Oz            Spices
# 104            Great Value Kosher Basil Leaves, 0.8 oz            Spices
# 105      Great Value Lemon & Pepper Seasoning, 4.25 oz            Spices
#
#          Category        ID                                  lower_description
# 0         Produce  75027076     marketside fresh vegetable medley blend, 12 oz
# 1         Produce  15186230                      fresh green bell pepper, each
# 2         Produce  26810050                              fresh cilantro, bunch
# 3         Produce  80385241                            fresh roma tomato, each
# 4         Produce  75384478  fresh jalapeno pepper, approx. 3-5 per 0.25 pound
# 5         Produce  56212846                               fresh cucumber, each
# 6         Produce  22176614         marketside fresh spinach, 10 oz bag, fresh
# 7          Frozen  43399012        great value chopped spinach, 12 oz (frozen)
# 8          Frozen  23298252  great value steamable mixed vegetables, frozen...
# 9          Frozen  11322312  great value broccoli & cauliflower, 12 oz (fro...
# 10         Frozen  17662207  great value frozen peas & carrots, 12 oz steam...
# 11        Produce  27367256                             fresh honeycrisp apple
# 12        Produce  33839573  del monte red grapefruit in 100% juice, 20.0 o...
# 13        Produce  62541273                        fresh clementines, 3 lb bag
# 14        Produce  61538987  fresh green seedless grapes, bag (2.25 lbs/bag...
# 15        Produce  22269432                  fresh honeycrisp apples, 3 lb bag
# 16        Produce  28281367                   fresh strawberries, 1 lb package
# 17        Produce  25748686  fresh red seedless grapes, bag (2.25 lbs/bag e...
# 18        Produce  58294521                     fresh granny smith apple, each
# 19        Produce  20568340                             fresh cantaloupe, each
# 20        Produce  38584435                                   fresh plum, each
# 21        Produce  43893060                         fresh mangoes, each, sweet
# 22        Produce  97306627                 fresh blueberries, 18 oz container
# 23        Produce  19638038                      fresh navel oranges, 4 lb bag
# 24         Frozen  29960676            great value blueberries, 48 oz (frozen)
# 25         Frozen  43419384  tru fru natures strawberries frozen fresh in w...
# 26         Frozen  94073192       great value frozen whole berry medley, 16 oz
# 27           Meat  42999588  great value, mild ground italian sausage, pork...
# 28           Meat  11027088  johnsonville beddar with cheddar smoked sausag...
# 29           Meat  54303793  smithfield marinated roasted garlic & herb fre...
# 30           Meat  83143031  pork country style ribs boneless, 1.1 - 2.5 lb...
# 31           Meat  61382069      pork ribeye chops boneless, 2.0 - 3.3 lb tray
# 32           Meat  19701528  smithfield fresh pork center cut loin boneless...
# 33           Meat  97185387  pork center cut loin chops bone-in, 1.6 - 2.6 ...
# 34           Meat  64583374         pork stew meat boneless, 0.9 - 2.0 lb tray
# 35           Meat  64772664  shady brook farms® 93% lean / 7% fat ground tu...
# 36           Meat  34503914  shady brook farms® turkey drumsticks, 3 pieces...
# 37           Meat  54441882  villari brothers, 100% gluten free, hickory sm...
# 38           Meat  64742009  butterball original seasoned frozen turkey bur...
# 39           Meat  60405425  land o' frost premium honey smoked turkey brea...
# 40           Meat  90180282  all natural* 80% lean/20% fat ground beef chuc...
# 41           Meat  15340607  beef choice angus chuck roast, 2.25 - 3.38 lb ...
# 42           Meat  80750395   beef bottom round steak thin, 0.34 - 2.0 lb tray
# 43           Meat  90907898  all natural* 93% lean/7% fat lean ground beef,...
# 44           Meat  45782965  all natural* 73% lean/27% fat ground beef, 3 l...
# 45        Seafood  54809043  great value frozen raw jumbo shell-on, tail-on...
# 46        Seafood  14284622  great value frozen wild caught pacific whiting...
# 47        Seafood  70933043        dockside classics premium crab cakes, 12 oz
# 48        Seafood  97919198  fresh skinless atlantic salmon portions, 0.95 ...
# 49        Seafood  84346449  military surplus freeze dried salmon fillets l...
# 50        Seafood  11492043  transocean seafood snackers, snack size leg st...
# 51        Seafood  53087946  great value frozen tilapia skinless & boneless...
# 52        Seafood  67446815            bumble bee tuna, teriyaki 2.5 oz. pouch
# 53        Seafood  29855185  chicken of the sea wild caught alaskan pink sa...
# 54        Seafood  31146450  ecuagold frozen raw shrimp head-on, 2 lb (14-2...
# 55        Seafood  10985992  primewaters atlantic salmon, traceable and sus...
# 56         Bakery  96580619          freshness guaranteed mini pecan pie, 4 oz
# 57        Produce  69233670   wholly guacamole spicy avocado verde salsa 10 oz
# 58        Produce  74604720  wholly guacamole classic mild mini single serv...
# 59        Produce  16286789                 wholly guacamole chunky bowl 15 oz
# 60        Produce  90760817  sabra snackers fresh guacamole dip and rolled ...
# 61        Produce  69585070                          fresh hass avocados, each
# 62        Produce  35846032            fresh small hass avocado bag, 5-6 count
# 63        Produce  76012560           fresh large hass avocado bag, 3- 4 count
# 64          Dairy  95822362          kraft parmesan grated cheese, 8 oz shaker
# 65          Dairy  50398908       great value sweet cream salted butter, 16 oz
# 66          Dairy  76308524  great value cream cheese brick, 8 oz (refriger...
# 67          Dairy  72826544  daisy pure and natural sour cream, regular,16 ...
# 68          Dairy  20948612  great value finely shredded sharp cheddar chee...
# 69          Dairy  86734659  great value mozzarella string cheese sticks, 1...
# 70          Dairy  48707750                          lactaid whole milk, 96 oz
# 71          Dairy  84760470                 lactaid 2% reduced fat milk, 96 oz
# 72          Dairy  88830651     great value 1% low fat milk, gallon, 128 fl oz
# 73          Dairy  14769374  great value skim fat free milk, half gallon, 6...
# 74          Dairy  65794898  horizon organic whole high vitamin d milk, hal...
# 75        Produce  67889329  great value cage free white eggs, large, 18 count
# 76        Produce  29359577  nellie's free-range grade a brown eggs, large,...
# 77           Soap  34793644  irish spring bar soap for men, aloe mist deodo...
# 78           Soap  84904598  softsoap liquid hand soap refill, aquarium, 50 oz
# 79           Soap  55182463                   dove white beauty bar 4 oz, 8 ct
# 80           Soap  85555680  coast refreshing deodorant bar soap, classic s...
# 81           Soap  11054235  kirk's original fresh scent gentle castile soa...
# 82           Soap  84253908  purex liquid laundry detergent, mountain breez...
# 83           Soap  29118709  persil discs laundry detergent pacs, original,...
# 84           Soap  21015587  tide simply liquid laundry detergent, refreshi...
# 85           Soap  46603602  xtra plus oxiclean, 131 loads liquid laundry d...
# 86           Soap  44445131  tide power pods laundry detergent soap packs w...
# 87   Italian Food  80204054            barilla classic mini penne pasta, 16 oz
# 88   Italian Food  72844995                    great value rotini pasta, 16 oz
# 89   Italian Food  51694287  knorr pasta sides chicken fettuccine, cooks in...
# 90   Italian Food  42847357                        great value linguine, 16 oz
# 91   Italian Food  28681291  ragu old world style traditional sauce, made w...
# 92   Italian Food  17003180  ragu chunky tomato, garlic and onion pasta sau...
# 93   Italian Food  86141923  classico tomato & basil spaghetti pasta sauce,...
# 94   Italian Food  24882746  prego pasta sauce, italian tomato sauce with r...
# 95   Italian Food  57307374  rao's homemade tomato sauce | tomato basil | 2...
# 96   Italian Food  83076756     great value classic alfredo pasta sauce, 16 oz
# 97   Italian Food  72000779         great value traditional pasta sauce, 24 oz
# 98     Condiments  49218328  mccormick cinnamon - ground, 2.37 oz mixed spi...
# 99     Condiments  67184539  mccormick garlic powder, 3.12 oz mixed spices ...
# 100    Condiments  66693687                        great value paprika, 2.5 oz
# 101    Condiments  73638965             great value italian seasoning, 0.95 oz
# 102    Condiments  96349461                   great value ground cumin, 2.5 oz
# 103    Condiments  71387403                 great value parsley flakes, 0.4 oz
# 104    Condiments  12479631            great value kosher basil leaves, 0.8 oz
# 105    Condiments  47079744      great value lemon & pepper seasoning, 4.25 oz
